# %% [markdown]
# # Amharic NER Labeling in CoNLL Format (Modular)
#
# This notebook demonstrates modular labeling of Amharic Telegram e-commerce messages for NER in CoNLL format, using helper functions from `src/utils/labeling_utils.py`.
#
# **Entity Types:**
# - B-Product, I-Product
# - B-LOC, I-LOC
# - B-PRICE, I-PRICE
# - O (Outside any entity)
#
# **Steps:**
# 1. Load the raw dataset from `data/raw/telegram_data.xlsx` using a utility function.
# 2. Tokenize each message using a utility function.
# 3. Label each token.
# 4. Save in CoNLL format using a utility function.

# %%
import sys
sys.path.append('../')  # So we can import from src/utils
from src.utils.labeling_utils import load_telegram_messages_xlsx, tokenize_message, label_tokens, save_conll_format
import os

DATA_PATH = '../data/raw/telegram_data.xlsx'
OUTPUT_PATH = '../data/raw/labeled_conll.txt'

# %%
# Load 40 messages
messages_df = load_telegram_messages_xlsx(DATA_PATH, n=40)
messages_df.head()
# Out:
#                                              Message
# 0  💥Anti slip tape\n\n👉ደረጃ ወይም የተለያዩ ቦታዎች እንዳያንሸራ...
# 1  💥Garlic press Chopper\n\n🔰Kitchen ginger garli...
# 2  💥 Color changing Set of 3 Luma Candles\n\n\nBr...
# 3             👉Anti-theft Lightweight Backpack 15.6"
# 4  💥የእንቁላልና የክሬም መምቻ \n\n👉 ባለ ሶስት የኬክ ፓትራና\n\n👉የእ...

# %% [markdown]
# ## Labeling Helper
# For each message, tokenize and label. Edit the `labels` list for each message.

# %%
labeled_messages = []
for idx, row in messages_df.iterrows():
    message = row['Message']
    tokens = tokenize_message(message)
    print(f'\nMessage {idx+1}: {message}')
    print('Tokens:', tokens)
    # ---- LABEL HERE ----
    # Example: all O (change manually for real labeling)
    labels = ['O'] * len(tokens)
    # Uncomment and edit the line below to label entities
    # labels = ['B-Product', 'I-Product', 'O', ...]  # length must match tokens
    # ----------------------
    labeled = label_tokens(tokens, labels)
    labeled_messages.append(labeled)
# Out:
# Message 1: 💥Anti slip tape
#
# 👉ደረጃ ወይም የተለያዩ ቦታዎች እንዳያንሸራትት የሚለጠፍ ፕላስተር
#
# ✨size:-50mm*5meter
#
#
#           ዋጋ:-500ብር
#
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Anti', 'slip', 'tape', '👉ደረጃ', 'ወይም', 'የተለያዩ', 'ቦታዎች', 'እንዳያንሸራትት', 'የሚለጠፍ', 'ፕላስተር', '✨size:-50mm*5meter', 'ዋጋ:-500ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 2: 💥Garlic press Chopper
#
# 🔰Kitchen ginger garlic press.Quick grinding.Saving you time.
# 🔰Manual extrusion and grinding.
# 🔰Stainless steel material.Food grade safety material.Durable and easy to clean.
# 🔰Curved plastic handle.Comfortable to use.
#
# ዋጋ፦  💰🏷 250 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Garlic', 'press', 'Chopper', '🔰Kitchen', 'ginger', 'garlic', 'press.Quick', 'grinding.Saving', 'you', 'time.', '🔰Manual', 'extrusion', 'and', 'grinding.', '🔰Stainless', 'steel', 'material.Food', 'grade', 'safety', 'material.Durable', 'and', 'easy', 'to', 'clean.', '🔰Curved', 'plastic', 'handle.Comfortable', 'to', 'use.', 'ዋጋ፦', '💰🏷', '250', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 3: 💥 Color changing Set of 3 Luma Candles
#
#
# Brand: Luma Candles
#
# 📈Color-Changing Ambiance
# 📈Realistic Flameless Flicker
# 📈Safe & No Flame
# 📈Battery-Powered
# 📈Remote Control
# 📈Relax & Enjoy Light Show
#
#
# ⭕️ Each Candle Requires 3AAA Batteries (not included)
#
# #Package_Includes:
# 3× Candles
# 1× Remote Control
#
#       ዋጋ:-1300ብር✅
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥', 'Color', 'changing', 'Set', 'of', '3', 'Luma', 'Candles', 'Brand:', 'Luma', 'Candles', '📈Color-Changing', 'Ambiance', '📈Realistic', 'Flameless', 'Flicker', '📈Safe', '&', 'No', 'Flame', '📈Battery-Powered', '📈Remote', 'Control', '📈Relax', '&', 'Enjoy', 'Light', 'Show', '⭕️', 'Each', 'Candle', 'Requires', '3AAA', 'Batteries', '(not', 'included)', '#Package_Includes:', '3×', 'Candles', '1×', 'Remote', 'Control', 'ዋጋ:-1300ብር✅', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 4: 👉Anti-theft Lightweight Backpack 15.6"
# Tokens: ['👉Anti-theft', 'Lightweight', 'Backpack', '15.6"']
#
# Message 5: 💥የእንቁላልና የክሬም መምቻ
#
# 👉 ባለ ሶስት የኬክ ፓትራና
#
# 👉የእንቁላል መምቻው መለዋወጫ ያለው
#
# 👉ፓትራው በክብ በአራት መዓዘንና በልብቅርፅ ያለው
#
#           ዋጋ:-1900ብር✅✅
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥የእንቁላልና', 'የክሬም', 'መምቻ', '👉', 'ባለ', 'ሶስት', 'የኬክ', 'ፓትራና', '👉የእንቁላል', 'መምቻው', 'መለዋወጫ', 'ያለው', '👉ፓትራው', 'በክብ', 'በአራት', 'መዓዘንና', 'በልብቅርፅ', 'ያለው', 'ዋጋ:-1900ብር✅✅', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 6: ❇️ Adjustable Laptop & Tablet Stand (የብረቱ)
# 💯High Quality
#
# ✔️ላፕቶፕ ጭን ላይ አስቀምጠው መጠቀም ለከፋ ጉዳት እንደሚያጋልጥ የጤና ባለሙያዎች ይናገራሉ ፤ እንዲሁም ቴብል ላይ አድርገዉ ሲጠቀሙ ፋኑ ስለሚደፈን  ከፍተኛ ሙቀት በመጠር ድምፅ ያሰማል።
# 👉ለዚህ ሁሉ መፍትሄ ተጣጣፊ የላፕቶፕ ፣ ታብሌት Holder በተመጣጣኝ ዋጋ ገዝተዉ የእርስዎንና የላፕቶፕዎን ጤንነት ይጠብቁ።
#
# 🔥 Available Color:
#
#
#           ዋጋ፦ ✅  1000
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['❇️', 'Adjustable', 'Laptop', '&', 'Tablet', 'Stand', '(የብረቱ)', '💯High', 'Quality', '✔️ላፕቶፕ', 'ጭን', 'ላይ', 'አስቀምጠው', 'መጠቀም', 'ለከፋ', 'ጉዳት', 'እንደሚያጋልጥ', 'የጤና', 'ባለሙያዎች', 'ይናገራሉ', '፤', 'እንዲሁም', 'ቴብል', 'ላይ', 'አድርገዉ', 'ሲጠቀሙ', 'ፋኑ', 'ስለሚደፈን', 'ከፍተኛ', 'ሙቀት', 'በመጠር', 'ድምፅ', 'ያሰማል።', '👉ለዚህ', 'ሁሉ', 'መፍትሄ', 'ተጣጣፊ', 'የላፕቶፕ', '፣', 'ታብሌት', 'Holder', 'በተመጣጣኝ', 'ዋጋ', 'ገዝተዉ', 'የእርስዎንና', 'የላፕቶፕዎን', 'ጤንነት', 'ይጠብቁ።', '🔥', 'Available', 'Color:', 'ዋጋ፦', '✅', '1000', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 7: 🎯 Reusable Paper Towels Lazy Rag
# 👉100pc sheets (ትልቁ)
# 👉 Non-woven kitchen cleaning cloths can be reused again
# 👉Great for wiping the kitchen ,counter, stove, appliances.
# 👉high oil absorbation
# 👉Washable, durable use
# 👉Effectively remove dirt and oil stains
# 👉Good water absorption,
# 👉no water mark after wiping
# 📌Size: 25*25 CM / Sheet 100PCS/ Roll (ትልቁ)
#
# #Multifunction:
# 🪞wash dishes,
# 🪞wash fruits,
# 🪞thermal insulation pads,
# 🪞clean car and so on
#
# ዋጋ፦  💰🏷  500 ብር
#
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🎯', 'Reusable', 'Paper', 'Towels', 'Lazy', 'Rag', '👉100pc', 'sheets', '(ትልቁ)', '👉', 'Non-woven', 'kitchen', 'cleaning', 'cloths', 'can', 'be', 'reused', 'again', '👉Great', 'for', 'wiping', 'the', 'kitchen', ',counter,', 'stove,', 'appliances.', '👉high', 'oil', 'absorbation', '👉Washable,', 'durable', 'use', '👉Effectively', 'remove', 'dirt', 'and', 'oil', 'stains', '👉Good', 'water', 'absorption,', '👉no', 'water', 'mark', 'after', 'wiping', '📌Size:', '25*25', 'CM', '/', 'Sheet', '100PCS/', 'Roll', '(ትልቁ)', '#Multifunction:', '🪞wash', 'dishes,', '🪞wash', 'fruits,', '🪞thermal', 'insulation', 'pads,', '🪞clean', 'car', 'and', 'so', 'on', 'ዋጋ፦', '💰🏷', '500', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 8: ❇️ 3in1 colorful water bottle
#       💯High Quality
# 💥package includes👉2litter,
#                                      👉900ml
#                                       👉300ml
#
#
# 👉Motivational design-gives you motivation, reminds you to stay hydrated and drink enough water throughout the day
#
# 👉Convenient to carry
#
#
#  💦 ዋጋ፦ 1300ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['❇️', '3in1', 'colorful', 'water', 'bottle', '💯High', 'Quality', '💥package', 'includes👉2litter,', '👉900ml', '👉300ml', '👉Motivational', 'design-gives', 'you', 'motivation,', 'reminds', 'you', 'to', 'stay', 'hydrated', 'and', 'drink', 'enough', 'water', 'throughout', 'the', 'day', '👉Convenient', 'to', 'carry', '💦', 'ዋጋ፦', '1300ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 9: 💥Head protector helmet for kids
#
#    ዋጋ:-550ብር
#
# #Sheger_online_store
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Head', 'protector', 'helmet', 'for', 'kids', 'ዋጋ:-550ብር', '#Sheger_online_store', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 10: 🎯Origional panasonic® 4 in 1
#
# 🔰 ጥራት ያለው Made In Thailand
# 🔰 አራት ጥቅሞችን ያካተተ
#        👉 ፎም
#        👉 ማለስለሻ
#        👉 ከርል መስሪያ
# 🔰 ለማንኛውም ፀጉር ተስማሚ
#
# ዋጋ፦  💰🏷  3500 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🎯Origional', 'panasonic®', '4', 'in', '1', '🔰', 'ጥራት', 'ያለው', 'Made', 'In', 'Thailand', '🔰', 'አራት', 'ጥቅሞችን', 'ያካተተ', '👉', 'ፎም', '👉', 'ማለስለሻ', '👉', 'ከርል', 'መስሪያ', '🔰', 'ለማንኛውም', 'ፀጉር', 'ተስማሚ', 'ዋጋ፦', '💰🏷', '3500', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 11: 🎉🎉 #ልዩ_የበአል_ቅናሽ_እንደቀጠለ_ነው🎉🎉
# ❇️ Knife Sharpener Tool
#
# ✔️Stylish and safety design,
# ✔️Easy to clean and storage
# ✔️ 3 stages of sharpening ( Fine, Ceramic and coarse ), ensure the perfect sharpening resulting
#
#
#           💦 ዋጋ፦  450ብር❌❌
#
#                                400ብር✅✅
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🎉🎉', '#ልዩ_የበአል_ቅናሽ_እንደቀጠለ_ነው🎉🎉', '❇️', 'Knife', 'Sharpener', 'Tool', '✔️Stylish', 'and', 'safety', 'design,', '✔️Easy', 'to', 'clean', 'and', 'storage', '✔️', '3', 'stages', 'of', 'sharpening', '(', 'Fine,', 'Ceramic', 'and', 'coarse', '),', 'ensure', 'the', 'perfect', 'sharpening', 'resulting', '💦', 'ዋጋ፦', '450ብር❌❌', '400ብር✅✅', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 12: ❇️ Wall-Mounted Toilet Cleaning Brush With Brush Holder
#
# ✔️High Quality Toilet Brush
# ✔️Deeper Cleaning
# ✔️Comfortable Handle Design
#
#
#
# #Package_Included:
# 1 x Toilet Brush
# 1 x Toilet Brush Holder
#
#
#           💦 ዋጋ፦ ✅ 450
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['❇️', 'Wall-Mounted', 'Toilet', 'Cleaning', 'Brush', 'With', 'Brush', 'Holder', '✔️High', 'Quality', 'Toilet', 'Brush', '✔️Deeper', 'Cleaning', '✔️Comfortable', 'Handle', 'Design', '#Package_Included:', '1', 'x', 'Toilet', 'Brush', '1', 'x', 'Toilet', 'Brush', 'Holder', '💦', 'ዋጋ፦', '✅', '450', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 13: 👉Reusable Paper Towels Lazy Rag
# Tokens: ['👉Reusable', 'Paper', 'Towels', 'Lazy', 'Rag']
#
# Message 14: 🎯 Helping Handle👆👆👆
# Tokens: ['🎯', 'Helping', 'Handle👆👆👆']
#
# Message 15: 💥Over Toilet Storage Rack
#
# 👉የቦታ ጥበት ካለብዎ ይሄ ያስፈልግዎታል
# 👉 Toilet/Kitchen ላይ ሊጠቀሙበት ይችላሉ
# 👉የንፅህና ዕቃዎችን፣ የግሮሰሪና ዕቃዎችን፣ ኮስሞቲክሶች እና አትክልት/ፍራፍሬዎችን ሊያስቀምጡበት ይችላሉ
# 👉 ግድግዳ መብሳት አያስፈልግዎትም
# 👉 ከጠንካራ ብረት እና ፕላስቲክ የተሰራ
# 👉 እርጥበትን የሚቋቋም የማይዝግ
# 👉 ማያያዣ ሁክ ያለው
#
#          ዋጋ ፦1100 ብር✅✅
#
# ♦️ውስን ፍሬ ነው ያለው
#
#     🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Over', 'Toilet', 'Storage', 'Rack', '👉የቦታ', 'ጥበት', 'ካለብዎ', 'ይሄ', 'ያስፈልግዎታል', '👉', 'Toilet/Kitchen', 'ላይ', 'ሊጠቀሙበት', 'ይችላሉ', '👉የንፅህና', 'ዕቃዎችን፣', 'የግሮሰሪና', 'ዕቃዎችን፣', 'ኮስሞቲክሶች', 'እና', 'አትክልት/ፍራፍሬዎችን', 'ሊያስቀምጡበት', 'ይችላሉ', '👉', 'ግድግዳ', 'መብሳት', 'አያስፈልግዎትም', '👉', 'ከጠንካራ', 'ብረት', 'እና', 'ፕላስቲክ', 'የተሰራ', '👉', 'እርጥበትን', 'የሚቋቋም', 'የማይዝግ', '👉', 'ማያያዣ', 'ሁክ', 'ያለው', 'ዋጋ', '፦1100', 'ብር✅✅', '♦️ውስን', 'ፍሬ', 'ነው', 'ያለው', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 16: 💥ተጣጣፊ የእቃ ማስቀመጫ እና ማድረቂያ
# 💥foldable dish drying and drainer rack
#
#      ዋጋ-800ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥ተጣጣፊ', 'የእቃ', 'ማስቀመጫ', 'እና', 'ማድረቂያ', '💥foldable', 'dish', 'drying', 'and', 'drainer', 'rack', 'ዋጋ-800ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 17: 💥Flame Aroma Diffuser Humidifier
#
# 👉በኤሌክትሪክ የሚሰራ
# 👉 ለቤት መልካም መዓዛን የሚሰጥ
#
# 🚩Capacity: 200ml
# 🚩Purify the air & Beautify the Environment
#
#
# 👉very effective: Usb power interface, convenient and quick operation, can be used anywhere.
#
#               ዋጋ፦ 1,500 ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Flame', 'Aroma', 'Diffuser', 'Humidifier', '👉በኤሌክትሪክ', 'የሚሰራ', '👉', 'ለቤት', 'መልካም', 'መዓዛን', 'የሚሰጥ', '🚩Capacity:', '200ml', '🚩Purify', 'the', 'air', '&', 'Beautify', 'the', 'Environment', '👉very', 'effective:', 'Usb', 'power', 'interface,', 'convenient', 'and', 'quick', 'operation,', 'can', 'be', 'used', 'anywhere.', 'ዋጋ፦', '1,500', 'ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 18: 💥 Non-Woven closset drawer organizer box
#
# 👉foldable and has two sided visibility
# 👉 does not take up space
#
#    ዋጋ 👉 1200 ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥', 'Non-Woven', 'closset', 'drawer', 'organizer', 'box', '👉foldable', 'and', 'has', 'two', 'sided', 'visibility', '👉', 'does', 'not', 'take', 'up', 'space', 'ዋጋ', '👉', '1200', 'ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 19: 🎯Adjustable Baby Shower Cap Child Kids Shampoo Bath Hat Wash Hair Shield
#
# ዋጋ፦  💰🏷  200 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A (ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
# Tokens: ['🎯Adjustable', 'Baby', 'Shower', 'Cap', 'Child', 'Kids', 'Shampoo', 'Bath', 'Hat', 'Wash', 'Hair', 'Shield', 'ዋጋ፦', '💰🏷', '200', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A', '(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore']
#
# Message 20: 💥 360° የሚሽከረከር የጥራጥሬ ማስቀመጫ
#
# 👉የራሱ መቀነሻ ያለው
# 👉በፈለግነው መጠን መቀነስ የሚያስችል
# 👉ለሩዝና ለጥራጥሬ
# 👉የኪችናችን ውበት እና ስርአት ከፍ የሚያደርግ
#
# ዋጋ፦  💰🏷  3200ብር✅✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥', '360°', 'የሚሽከረከር', 'የጥራጥሬ', 'ማስቀመጫ', '👉የራሱ', 'መቀነሻ', 'ያለው', '👉በፈለግነው', 'መጠን', 'መቀነስ', 'የሚያስችል', '👉ለሩዝና', 'ለጥራጥሬ', '👉የኪችናችን', 'ውበት', 'እና', 'ስርአት', 'ከፍ', 'የሚያደርግ', 'ዋጋ፦', '💰🏷', '3200ብር✅✅', '♦️ውስን', 'ፍሬ', 'ነው', 'ያለው', '🔥🔥🔥', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 21: ❇️ Foldable Barbecue Grill With Stand
#               💯High Quality
#
# 📌#Brand: #Royalford
#
# ⚡ለወዳጅ ዘመድዎ የሚሰጡት ምርጥ ስጦታ
# ⚡ሙቀት-ተከላካይ እና ጭረት-ተከላካይ
# ⚡ከተጠቀሙ በኋላ አጣጥፈው ማስቀመጥ ይችላሉ
# ⚡ሲጠቀሙ ጠፍጣፋ ፣ ጠንካራ ወለል ወይም ጠረጴዛ ላይ ይጠቀሙበት
# ⚡የመጋገሪያው መረብ ሊወጣ ስለሚችል ለማፅዳት ቀላል ነው
#
# #Stainless_Steel_Charcoal_BBQ_Grill
# ✔ Premium Quantity Material
# ✔Easy to carry
# ✔Perfect for 3-5 people beach family/party
# ✔Heat-resistant and scratch-resistant
# ✔It can be folded away after you use
# ✔Use it on a flat, sturdy surface or table
# ✔Easy to clean as the baking net can be pulled out
# ✔Perfect Gift
#
#
# 📌#Size: 35×27×20CM
#
#
#       💦 ዋጋ፦ ✅️ 1,900 ብር
#
# ❌ውስን ፍሬ ነው ያለን
#
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['❇️', 'Foldable', 'Barbecue', 'Grill', 'With', 'Stand', '💯High', 'Quality', '📌#Brand:', '#Royalford', '⚡ለወዳጅ', 'ዘመድዎ', 'የሚሰጡት', 'ምርጥ', 'ስጦታ', '⚡ሙቀት-ተከላካይ', 'እና', 'ጭረት-ተከላካይ', '⚡ከተጠቀሙ', 'በኋላ', 'አጣጥፈው', 'ማስቀመጥ', 'ይችላሉ', '⚡ሲጠቀሙ', 'ጠፍጣፋ', '፣', 'ጠንካራ', 'ወለል', 'ወይም', 'ጠረጴዛ', 'ላይ', 'ይጠቀሙበት', '⚡የመጋገሪያው', 'መረብ', 'ሊወጣ', 'ስለሚችል', 'ለማፅዳት', 'ቀላል', 'ነው', '#Stainless_Steel_Charcoal_BBQ_Grill', '✔', 'Premium', 'Quantity', 'Material', '✔Easy', 'to', 'carry', '✔Perfect', 'for', '3-5', 'people', 'beach', 'family/party', '✔Heat-resistant', 'and', 'scratch-resistant', '✔It', 'can', 'be', 'folded', 'away', 'after', 'you', 'use', '✔Use', 'it', 'on', 'a', 'flat,', 'sturdy', 'surface', 'or', 'table', '✔Easy', 'to', 'clean', 'as', 'the', 'baking', 'net', 'can', 'be', 'pulled', 'out', '✔Perfect', 'Gift', '📌#Size:', '35×27×20CM', '💦', 'ዋጋ፦', '✅️', '1,900', 'ብር', '❌ውስን', 'ፍሬ', 'ነው', 'ያለን', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 22: 🎯 Soap Pump Dispenser with Sponge
#
# 🔰Dispense the perfect amount of dish soap, Every time!!
# 🔰Tank Capacity: 385ml
#
# ዋጋ፦  💰🏷    350 ብር ✅✅
#
# ♦️ውስን ፍሬ ነው ያለው
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05/SL-06 (ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🎯', 'Soap', 'Pump', 'Dispenser', 'with', 'Sponge', '🔰Dispense', 'the', 'perfect', 'amount', 'of', 'dish', 'soap,', 'Every', 'time!!', '🔰Tank', 'Capacity:', '385ml', 'ዋጋ፦', '💰🏷', '350', 'ብር', '✅✅', '♦️ውስን', 'ፍሬ', 'ነው', 'ያለው', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05/SL-06', '(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 23: 🎄🎄🎄🎄እንኮን አደረሳችሁ 🎄🎄🎄
#
# #ልዩ የ በዓል ቅናሽ እንደቀጠለ ነው🎄🎄💥
#
# 🎯12pcs Silicone Kitchen Set
#   230°c ድረስ መቆቆም እሚችል
#
# ዋጋ፦  💰🏷  1800ብር❌❌
#                        1600ብር✅✅
#      💧💧💧💧
#
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05/SL-06 (ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
# Tokens: ['🎄🎄🎄🎄እንኮን', 'አደረሳችሁ', '🎄🎄🎄', '#ልዩ', 'የ', 'በዓል', 'ቅናሽ', 'እንደቀጠለ', 'ነው🎄🎄💥', '🎯12pcs', 'Silicone', 'Kitchen', 'Set', '230°c', 'ድረስ', 'መቆቆም', 'እሚችል', 'ዋጋ፦', '💰🏷', '1800ብር❌❌', '1600ብር✅✅', '💧💧💧💧', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05/SL-06', '(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore']
#
# Message 24: 💥New born to toddler rocker
#           2023model🔥🔥🔥
#        high quality 💯💯💯
#
# 👉ከልጆች እድገት ጋር አብሮ የሚያድግ
# 👉የራሱ ቫይብሬሽን ያለው
# 👉በጣም ምቹ መተኛ
# 👉ወደ ዃላ መተኛት ቀና ማለት የሚችል
# 👉ለልጆች ከፍ ሲሉ እነደ መመገቢያም የሚጠቀሙበት
# 👉it starts as a comfy calming infant seat,then becomes a toddler rocker.
# 👉folds easily for stowing or going
# 👉0-36months
#
#         ዋጋ:-7800ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥New', 'born', 'to', 'toddler', 'rocker', '2023model🔥🔥🔥', 'high', 'quality', '💯💯💯', '👉ከልጆች', 'እድገት', 'ጋር', 'አብሮ', 'የሚያድግ', '👉የራሱ', 'ቫይብሬሽን', 'ያለው', '👉በጣም', 'ምቹ', 'መተኛ', '👉ወደ', 'ዃላ', 'መተኛት', 'ቀና', 'ማለት', 'የሚችል', '👉ለልጆች', 'ከፍ', 'ሲሉ', 'እነደ', 'መመገቢያም', 'የሚጠቀሙበት', '👉it', 'starts', 'as', 'a', 'comfy', 'calming', 'infant', 'seat,then', 'becomes', 'a', 'toddler', 'rocker.', '👉folds', 'easily', 'for', 'stowing', 'or', 'going', '👉0-36months', 'ዋጋ:-7800ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 25: 🎯 Silicon Back Scrub
#
# 🔰Cleanse & refresh skin with a gentle lather
# 🔰 Great for household cleaning & scrubbing
# 🔰 Double-sided, can be easily extracted
# 🔰 Soft and comfortable
# 🔰 Easy to clean
# 🔰 Size: 70x11.5cm
#
# ዋጋ፦  💰🏷  350 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A (ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🎯', 'Silicon', 'Back', 'Scrub', '🔰Cleanse', '&', 'refresh', 'skin', 'with', 'a', 'gentle', 'lather', '🔰', 'Great', 'for', 'household', 'cleaning', '&', 'scrubbing', '🔰', 'Double-sided,', 'can', 'be', 'easily', 'extracted', '🔰', 'Soft', 'and', 'comfortable', '🔰', 'Easy', 'to', 'clean', '🔰', 'Size:', '70x11.5cm', 'ዋጋ፦', '💰🏷', '350', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A', '(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 26: 💥SOAP BOX RACK
#
# ✔️የራሱ መለጠፊያ ስላለው ግድግዳ መብሳት አያስፈልግም
# ✔️ ሁለት ሳሙናዎችን እና አንድ ፎጣ የሚይዝ
#
#       ዋጋ፦ ✅ 400 ብር
#
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥SOAP', 'BOX', 'RACK', '✔️የራሱ', 'መለጠፊያ', 'ስላለው', 'ግድግዳ', 'መብሳት', 'አያስፈልግም', '✔️', 'ሁለት', 'ሳሙናዎችን', 'እና', 'አንድ', 'ፎጣ', 'የሚይዝ', 'ዋጋ፦', '✅', '400', 'ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 27: 💥 Pet fur & Lint Remover
#
#     👉ብናኝን በቀላሉ የሚያፀዳ
#
#       ዋጋ፦ 750 ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥', 'Pet', 'fur', '&', 'Lint', 'Remover', '👉ብናኝን', 'በቀላሉ', 'የሚያፀዳ', 'ዋጋ፦', '750', 'ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 28: 💥Saachi Hot plate
# ሳቺ ባለሁለት ምድጃ ስቶቭ
#
#       💯orginal
#
# ⚡️ 2000 ዋት
# ⚡️ ፊውዝ የተገጠመለት
# ⚡️ ትልቅ ድስት መሸከም የሚችል
# ⚡️ አስተማማኝ ቴርሞስታት
# ⚡️ ባለ ፊውዝ
#
# ዋጋ፦ ትልቁ :- 2700ብር
#
#
# የሀገር ዉስጡ :-2000ብር
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Saachi', 'Hot', 'plate', 'ሳቺ', 'ባለሁለት', 'ምድጃ', 'ስቶቭ', '💯orginal', '⚡️', '2000', 'ዋት', '⚡️', 'ፊውዝ', 'የተገጠመለት', '⚡️', 'ትልቅ', 'ድስት', 'መሸከም', 'የሚችል', '⚡️', 'አስተማማኝ', 'ቴርሞስታት', '⚡️', 'ባለ', 'ፊውዝ', 'ዋጋ፦', 'ትልቁ', ':-', '2700ብር', 'የሀገር', 'ዉስጡ', ':-2000ብር', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 29: 💥የመስታዎት ፓትራዎች ( glass bakewares) 🥧 🥮
#
# 👉oval shape
#
# 👉ገበታ ላይ መቅረብ የሚችሉ ውብ የመስታዎት ፓትራዎች
#
# 👉ሶስት የተለያየ መጠን ያላቸው (3.0 ሊ ፣ 2.4 ሊ፣ 1.6ሊ ) ፓትራዎችን የያዘ
#
# 👉ለላዛኛ ፣ ፓስታ ፍርኖ፣ ኬክ  ተመራጭ
#
# 👉ውብና ማራኪ ገበታ ላይ  መቅረብ የሚችሉ
#
# 👉ውፍራም ማንኛውንም ሙቀት የሚቋቋም
#
# ዋጋ፦  💰🏷  ሶስቱን በ 3300 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥የመስታዎት', 'ፓትራዎች', '(', 'glass', 'bakewares)', '🥧', '🥮', '👉oval', 'shape', '👉ገበታ', 'ላይ', 'መቅረብ', 'የሚችሉ', 'ውብ', 'የመስታዎት', 'ፓትራዎች', '👉ሶስት', 'የተለያየ', 'መጠን', 'ያላቸው', '(3.0', 'ሊ', '፣', '2.4', 'ሊ፣', '1.6ሊ', ')', 'ፓትራዎችን', 'የያዘ', '👉ለላዛኛ', '፣', 'ፓስታ', 'ፍርኖ፣', 'ኬክ', 'ተመራጭ', '👉ውብና', 'ማራኪ', 'ገበታ', 'ላይ', 'መቅረብ', 'የሚችሉ', '👉ውፍራም', 'ማንኛውንም', 'ሙቀት', 'የሚቋቋም', 'ዋጋ፦', '💰🏷', 'ሶስቱን', 'በ', '3300', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 30: 💥boppy pillow
#
#
#
#    ዋጋ:- 900ብር✅✅
#
# ✖️ውስን ፍሬ ነው ያለው
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥boppy', 'pillow', 'ዋጋ:-', '900ብር✅✅', '✖️ውስን', 'ፍሬ', 'ነው', 'ያለው', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 31: 💥 Smiley Face Non Stick Pancake Pan 😂😆
#
# ⚡️ Granite coated pan
# ⚡️100% የማይዝ
# ⚡️ በአንድ ግዜ 7 ኬክ ይጋግራል
#
#   ዋጋ፦  💰 1700 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥', 'Smiley', 'Face', 'Non', 'Stick', 'Pancake', 'Pan', '😂😆', '⚡️', 'Granite', 'coated', 'pan', '⚡️100%', 'የማይዝ', '⚡️', 'በአንድ', 'ግዜ', '7', 'ኬክ', 'ይጋግራል', 'ዋጋ፦', '💰', '1700', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 32: 💥 single Set serving acrylic Tray with golden and silver handle
#
# ✨ለኬክ,ለፍሩት እና ለተለያዩ ዲዘርት ነገሮች ማቅረቢያ
# ✨ የማይጫጫር የማይመነችክ ሰርቪሶች
# ✨acrylic ስለሆነ ቶሎ አይሰበርም
# ✨እረጅም ጊዜ ውበቱን ጠብቆ የሚቆይ
#
#      ዋጋ:-1100ብር✅✅
#
# ❌ዉስን ፍሬ ነው ያለን❌
# ❌ limited stock❌
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥', 'single', 'Set', 'serving', 'acrylic', 'Tray', 'with', 'golden', 'and', 'silver', 'handle', '✨ለኬክ,ለፍሩት', 'እና', 'ለተለያዩ', 'ዲዘርት', 'ነገሮች', 'ማቅረቢያ', '✨', 'የማይጫጫር', 'የማይመነችክ', 'ሰርቪሶች', '✨acrylic', 'ስለሆነ', 'ቶሎ', 'አይሰበርም', '✨እረጅም', 'ጊዜ', 'ውበቱን', 'ጠብቆ', 'የሚቆይ', 'ዋጋ:-1100ብር✅✅', '❌ዉስን', 'ፍሬ', 'ነው', 'ያለን❌', '❌', 'limited', 'stock❌', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 33: 🎄🎄 ልዩ የገና በዓል ቅናሽ ተጀምሮል🎄🎄
#
# 💥sanford®👟👟👚👔 አነስተኛ የልብስ እና የጫማ  ማጠቢያ ማሽን 👟👔
# 👉 ለቲሸርት: ለጂንስ : ለሹራብ:ለአንሶላ ፣ጫማ
# 👉በጠቅላላው እስከ 2.5 kg የሚመዝን ልብስ በአንድ ጊዜ ማጠብ የሚችል
# 👉 በተጨማሪም ጫማ ማጠቢያ ቡሩሽ ያለው
# 👉የራሱ መጭመቂያ ያለው
# 👉አንድ አመት ዋስትና ያለው
# 👉አነስተኛ የኤሌክትሪክ ፍጆታ( ሀይል ቆጣቢ)
# ከቦታ ቦታ
# በቀላሉ ተንቀሳቃሽ፡ በጠባብ ቦታ መቀመጥ የሚችል
#
# ዋጋ፦  💰🏷  10,500 ብር❌❌
#
#                       9900ብር✅✅
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🎄🎄', 'ልዩ', 'የገና', 'በዓል', 'ቅናሽ', 'ተጀምሮል🎄🎄', '💥sanford®👟👟👚👔', 'አነስተኛ', 'የልብስ', 'እና', 'የጫማ', 'ማጠቢያ', 'ማሽን', '👟👔', '👉', 'ለቲሸርት:', 'ለጂንስ', ':', 'ለሹራብ:ለአንሶላ', '፣ጫማ', '👉በጠቅላላው', 'እስከ', '2.5', 'kg', 'የሚመዝን', 'ልብስ', 'በአንድ', 'ጊዜ', 'ማጠብ', 'የሚችል', '👉', 'በተጨማሪም', 'ጫማ', 'ማጠቢያ', 'ቡሩሽ', 'ያለው', '👉የራሱ', 'መጭመቂያ', 'ያለው', '👉አንድ', 'አመት', 'ዋስትና', 'ያለው', '👉አነስተኛ', 'የኤሌክትሪክ', 'ፍጆታ(', 'ሀይል', 'ቆጣቢ)', 'ከቦታ', 'ቦታ', 'በቀላሉ', 'ተንቀሳቃሽ፡', 'በጠባብ', 'ቦታ', 'መቀመጥ', 'የሚችል', 'ዋጋ፦', '💰🏷', '10,500', 'ብር❌❌', '9900ብር✅✅', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 34: 💥ክብ ሰርቢስ
#
#         ዋጋ:-600ብር
#
# ❌ዉስን ፍሬ ነው ያለን❌
# ❌ limited stock❌
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥ክብ', 'ሰርቢስ', 'ዋጋ:-600ብር', '❌ዉስን', 'ፍሬ', 'ነው', 'ያለን❌', '❌', 'limited', 'stock❌', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 35: 💥Hands free Bottle feeding pillow
#
#     🔰 ሁለት ጥቅም በአንድ ላይ
#         1. ትራስ
#         2. ጡጦ ለማጥባት   አመች
#
#      ዋጋ:-500ብር✅
#
#
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥Hands', 'free', 'Bottle', 'feeding', 'pillow', '🔰', 'ሁለት', 'ጥቅም', 'በአንድ', 'ላይ', '1.', 'ትራስ', '2.', 'ጡጦ', 'ለማጥባት', 'አመች', 'ዋጋ:-500ብር✅', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 36: 🎯 Burger press
#
# ዋጋ፦  💰🏷  350 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
# Tokens: ['🎯', 'Burger', 'press', 'ዋጋ፦', '💰🏷', '350', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore']
#
# Message 37: 💥የዘይት የቅቤ ማጥለያ እንዲሁም ማስቀመጫ
#
# 🔰የመያዝ አቅም 1.4ሊትር
#
#             ዋጋ፦850 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥የዘይት', 'የቅቤ', 'ማጥለያ', 'እንዲሁም', 'ማስቀመጫ', '🔰የመያዝ', 'አቅም', '1.4ሊትር', 'ዋጋ፦850', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 38: 💥8 JAR HANDLE SPICE
# 👉የቅመማ ቅመም ማስቀመጫ
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
#     ዋጋ፦  1500 ብር✅
#
# 🏢 አድራሻ  👉 መገናኛ ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['💥8', 'JAR', 'HANDLE', 'SPICE', '👉የቅመማ', 'ቅመም', 'ማስቀመጫ', 'ውስን', 'ፍሬ', 'ነው', 'የቀረው', '❌❌', 'ዋጋ፦', '1500', 'ብር✅', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 39: 🌟 Reusable convenience LVy Grip Tape
# 💯High Quality
# ®️ ውፍራም ቲክነስ ያለው አንደኛው
# #ሕይወትዎን_የሚያቀል_ፕላስተር
# ⚡️ቆራርጠን መጠቀም የምንችለዉ
# ⚡️በ ሁለቱም ጎን አጣብቆ መያዝ የሚችል
# ⚡️ታጥቦ እንደገና ጥቅም ላይ ሊውል የሚችል
# ⚡️ለስራ ቦታ ፣ለኪችንዎ... ተመራጭ
#
# 🪞Size: 3 Meter
# 🪞 Double Sided Tape
# 🪞Reusable,  Removable & Washable
# 🪞 Ivy Grip Tape Life Magic Tape
# 🪞Seamless hook,
# 🪞nano-sol all-purpose tape
#
#
# ዋጋ፦  💰🏷  3ሜትር 500 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# Tokens: ['🌟', 'Reusable', 'convenience', 'LVy', 'Grip', 'Tape', '💯High', 'Quality', '®️', 'ውፍራም', 'ቲክነስ', 'ያለው', 'አንደኛው', '#ሕይወትዎን_የሚያቀል_ፕላስተር', '⚡️ቆራርጠን', 'መጠቀም', 'የምንችለዉ', '⚡️በ', 'ሁለቱም', 'ጎን', 'አጣብቆ', 'መያዝ', 'የሚችል', '⚡️ታጥቦ', 'እንደገና', 'ጥቅም', 'ላይ', 'ሊውል', 'የሚችል', '⚡️ለስራ', 'ቦታ', '፣ለኪችንዎ...', 'ተመራጭ', '🪞Size:', '3', 'Meter', '🪞', 'Double', 'Sided', 'Tape', '🪞Reusable,', 'Removable', '&', 'Washable', '🪞', 'Ivy', 'Grip', 'Tape', 'Life', 'Magic', 'Tape', '🪞Seamless', 'hook,', '🪞nano-sol', 'all-purpose', 'tape', 'ዋጋ፦', '💰🏷', '3ሜትር', '500', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን⤵️', 'https://t.me/Shageronlinestore']
#
# Message 40: 🎯Adjustable Baby Shower Cap Child Kids Shampoo Bath Hat Wash Hair Shield
#
# ዋጋ፦  💰🏷  200 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ  👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A (ከ ሊፍቱ ፊት ለ ፊት)
#
#      💧💧💧💧
#
#
#     📲 0909522840
#     📲 0923350054
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
# Tokens: ['🎯Adjustable', 'Baby', 'Shower', 'Cap', 'Child', 'Kids', 'Shampoo', 'Bath', 'Hat', 'Wash', 'Hair', 'Shield', 'ዋጋ፦', '💰🏷', '200', 'ብር', '📍ውስን', 'ፍሬ', 'ነው', 'ያለን/', 'Limited', 'Stock', '🏢', 'አድራሻ', '👉', 'መገናኛ', 'ታሜ', 'ጋስ', 'ህንፃ', 'ጎን', 'ስሪ', 'ኤም', 'ሲቲ', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ.', 'SL-05A', '(ከ', 'ሊፍቱ', 'ፊት', 'ለ', 'ፊት)', '💧💧💧💧', '📲', '0909522840', '📲', '0923350054', '🔖', '💬', 'በTelegram', 'ለማዘዝ', '⤵️', 'ይጠቀሙ', '@shager_onlinestore']

# %% [markdown]
# ## Save Labeled Data in CoNLL Format

# %%
save_conll_format(labeled_messages, OUTPUT_PATH)
print(f'CoNLL labeled data saved to {OUTPUT_PATH}')
# Out:
# CoNLL labeled data saved to ../data/raw/labeled_conll.txt
